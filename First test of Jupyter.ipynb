# %%
import matplotlib.pyplot as plt
import numpy as np
import time
import pickle
from matplotlib.path import Path
from dirac_sheet import dirac_sheet
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %%
dx = .25
dt = 0.1
Ngrid = int(1802)
X_offset=112.5
myDirac=dirac_sheet(0,901,dt,dx,X_offset,0)
def test(x):

    myDirac.set_p(.5,np.pi*x/180)

    fig = plt.figure()
    plt.ion()
    plt.clf()
    plt.imshow(np.real(myDirac.u10),cmap='RdBu',interpolation='nearest', origin='lower')
    fig.canvas.draw()
interact(test, x=widgets.IntSlider(min=-90,max=90,step=1,value=0))
